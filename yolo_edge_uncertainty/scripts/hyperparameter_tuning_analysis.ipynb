# %%
import os
import sys
import json

# allow importing from parent directory
current_folder = globals()['_dh'][0]
data_location = os.path.join(current_folder,'data.csv')
sys.path.append(os.path.abspath(os.path.join(os.path.dirname(data_location), '../..')))

import pandas as pd
from matplotlib import pyplot as plt
from utlis_results import plot_tuning_results

from ultralytics import settings
settings.update({"sync": False})

pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 200)

FONT_SMALL = 23
FONT_MEDIUM = 25
FONT_LARGE = 27

plt.rcParams['font.size'] = FONT_LARGE
plt.rcParams['axes.labelsize'] = FONT_MEDIUM
plt.rcParams['xtick.labelsize'] = FONT_SMALL
plt.rcParams['ytick.labelsize'] = FONT_SMALL
plt.rcParams['legend.fontsize'] = FONT_SMALL
plt.rcParams['figure.titlesize'] = FONT_MEDIUM
plt.rcParams['axes.titlesize'] = FONT_MEDIUM
plt.rcParams['figure.figsize'] = (16, 8)

# %%
df = pd.read_csv('../../results/tuning/ensemble/results.csv')
plot_tuning_results(df, color_by='config/ensemble_dropout_rate', show=True)
plot_tuning_results(df, color_by='config/num_ensemble_heads');
# Out:
#     fitness  config/ensemble_dropout_rate  config/num_ensemble_heads  \
# 15  1.27685                      0.132089                          3
# 53  1.27672                      0.121077                          3
# 71  1.27646                      0.160218                          3
# 37  1.27633                      0.161845                          3
# 28  1.27620                      0.129518                          3
#
#                                           config/data  config/exist_ok  \
# 15  cityscapes-train-kitti-val-from-coco80-tuning....             True
# 53  cityscapes-train-kitti-val-from-coco80-tuning....             True
# 71  cityscapes-train-kitti-val-from-coco80-tuning....             True
# 37  cityscapes-train-kitti-val-from-coco80-tuning....             True
# 28  cityscapes-train-kitti-val-from-coco80-tuning....             True
#
#     config/epochs  config/imgsz  config/rect  config/save  config/fraction  \
# 15             50           640        False        False              1.0
# 53             50           640        False        False              1.0
# 71             50           640        False        False              1.0
# 37             50           640        False        False              1.0
# 28             50           640        False        False              1.0
#
#     config/val                                      config/freeze  config/box  \
# 15       False  ['0', '1', '2', '3', '4', '5', '6', '7', '8', ...         0.0
# 53       False  ['0', '1', '2', '3', '4', '5', '6', '7', '8', ...         0.0
# 71       False  ['0', '1', '2', '3', '4', '5', '6', '7', '8', ...         0.0
# 37       False  ['0', '1', '2', '3', '4', '5', '6', '7', '8', ...         0.0
# 28       False  ['0', '1', '2', '3', '4', '5', '6', '7', '8', ...         0.0
#
#     config/dfl  config/cls config/optimizer  config/lr0  config/lrf  \
# 15         0.0         1.0              SGD       0.001       0.001
# 53         0.0         1.0              SGD       0.001       0.001
# 71         0.0         1.0              SGD       0.001       0.001
# 37         0.0         1.0              SGD       0.001       0.001
# 28         0.0         1.0              SGD       0.001       0.001
#
#     config/momentum  config/weight_decay  config/batch  metrics/precision(B)  \
# 15              0.9               0.0005            16               0.50420
# 53              0.9               0.0005            16               0.51935
# 71              0.9               0.0005            16               0.54280
# 37              0.9               0.0005            16               0.54714
# 28              0.9               0.0005            16               0.50907
#
#     metrics/recall(B)  metrics/mAP50(B)  metrics/mAP50-95(B)  metrics/mUE50  \
# 15            0.38927           0.42360              0.21922        0.14675
# 53            0.38384           0.42346              0.21934        0.14674
# 71            0.36629           0.42274              0.21858        0.14628
# 37            0.36473           0.42307              0.21875        0.14674
# 28            0.38726           0.42315              0.21913        0.14695
#
#     metrics/mUE50_thres  metrics/mUE50-95  metrics/mUE50-95_thres  \
# 15              0.24622           0.12356                 0.18019
# 53              0.23328           0.12336                 0.17853
# 71              0.25806           0.12384                 0.18663
# 37              0.26050           0.12474                 0.18773
# 28              0.24548           0.12387                 0.18174
#
#     metrics/mUE50_correct  metrics/mUE50_incorrect  metrics/mUE50-95_correct  \
# 15                0.09219                  0.05455                   0.08189
# 53                0.09518                  0.05156                   0.08208
# 71                0.08972                  0.05656                   0.08115
# 37                0.08920                  0.05754                   0.08148
# 28                0.09242                  0.05453                   0.08170
#
#     metrics/mUE50-95_incorrect  metrics/FPR95_50  metrics/FPR95_50-95  \
# 15                     0.04167           0.52807              0.48770
# 53                     0.04129           0.52993              0.48585
# 71                     0.04269           0.53253              0.49761
# 37                     0.04326           0.53183              0.50103
# 28                     0.04217           0.52977              0.49736
#
#     metrics/AUROC50  metrics/AUROC50-95  metrics/E-AURC50  metrics/E-AURC50-95
# 15          0.91775             0.93110           0.01972              0.01253
# 53          0.91746             0.93131           0.01975              0.01251
# 71          0.91778             0.93087           0.01980              0.01260
# 37          0.91769             0.93017           0.01991              0.01268
# 28          0.91744             0.93080           0.01984              0.01258
# 📁 Saved figure: tuning_config_ensemble_dropout_rate_metrics_mAP50B_vs_metrics_mUE50.png and tuning_config_ensemble_dropout_rate_metrics_mAP50B_vs_metrics_mUE50.pdf
# 📁 Saved figure: tuning_config_num_ensemble_heads_metrics_mAP50B_vs_metrics_mUE50.png and tuning_config_num_ensemble_heads_metrics_mAP50B_vs_metrics_mUE50.pdf

# %%
df = pd.read_csv('../../results/tuning/mc-dropout/results.csv')
plot_tuning_results(df, color_by='config/mc_dropout_rate', show=True)
plot_tuning_results(df, color_by='config/num_mc_forward_passes');
# Out:
#     fitness  config/mc_dropout_rate  config/num_mc_forward_passes  \
# 7   1.26793                0.004425                             5
# 83  1.26744                0.342808                            20
# 75  1.26684                0.341332                            20
# 28  1.26683                0.356235                            20
# 62  1.26663                0.353108                            20
#
#                                           config/data  config/exist_ok  \
# 7   cityscapes-train-kitti-val-from-coco80-tuning....             True
# 83  cityscapes-train-kitti-val-from-coco80-tuning....             True
# 75  cityscapes-train-kitti-val-from-coco80-tuning....             True
# 28  cityscapes-train-kitti-val-from-coco80-tuning....             True
# 62  cityscapes-train-kitti-val-from-coco80-tuning....             True
#
#     config/epochs  config/imgsz  config/rect  config/save  config/fraction  \
# 7              50           640        False        False              1.0
# 83             50           640        False        False              1.0
# 75             50           640        False        False              1.0
# 28             50           640        False        False              1.0
# 62             50           640        False        False              1.0
#
#     config/val                                      config/freeze  config/box  \
# 7        False  ['0', '1', '2', '3', '4', '5', '6', '7', '8', ...         0.0
# 83       False  ['0', '1', '2', '3', '4', '5', '6', '7', '8', ...         0.0
# 75       False  ['0', '1', '2', '3', '4', '5', '6', '7', '8', ...         0.0
# 28       False  ['0', '1', '2', '3', '4', '5', '6', '7', '8', ...         0.0
# 62       False  ['0', '1', '2', '3', '4', '5', '6', '7', '8', ...         0.0
#
#     config/dfl  config/cls config/optimizer  config/lr0  config/lrf  \
# 7          0.0         1.0              SGD       0.001       0.001
# 83         0.0         1.0              SGD       0.001       0.001
# 75         0.0         1.0              SGD       0.001       0.001
# 28         0.0         1.0              SGD       0.001       0.001
# 62         0.0         1.0              SGD       0.001       0.001
#
#     config/momentum  config/weight_decay  config/batch  metrics/precision(B)  \
# 7               0.9               0.0005            16               0.53484
# 83              0.9               0.0005            16               0.53967
# 75              0.9               0.0005            16               0.53832
# 28              0.9               0.0005            16               0.53645
# 62              0.9               0.0005            16               0.53673
#
#     metrics/recall(B)  metrics/mAP50(B)  metrics/mAP50-95(B)  metrics/mUE50  \
# 7             0.38620           0.39910              0.21205        0.13117
# 83            0.38201           0.42934              0.22206        0.16190
# 75            0.38497           0.42862              0.22171        0.16178
# 28            0.38184           0.42826              0.22183        0.16143
# 62            0.38038           0.42842              0.22173        0.16179
#
#     metrics/mUE50_thres  metrics/mUE50-95  metrics/mUE50-95_thres  \
# 7               0.44458           0.10889                 0.26799
# 83              0.73926           0.14464                 0.68311
# 75              0.73730           0.14436                 0.67920
# 28              0.72852           0.14312                 0.68398
# 62              0.73779           0.14463                 0.68359
#
#     metrics/mUE50_correct  metrics/mUE50_incorrect  metrics/mUE50-95_correct  \
# 7                 0.07235                  0.05882                   0.06582
# 83                0.08992                  0.07198                   0.08063
# 75                0.08978                  0.07200                   0.08068
# 28                0.09345                  0.06798                   0.08082
# 62                0.09178                  0.07001                   0.08211
#
#     metrics/mUE50-95_incorrect  metrics/FPR95_50  metrics/FPR95_50-95  \
# 7                      0.04307           0.29666              0.25181
# 83                     0.06400           0.59187              0.59321
# 75                     0.06368           0.59622              0.61090
# 28                     0.06230           0.59199              0.60517
# 62                     0.06251           0.58969              0.60673
#
#     metrics/AUROC50  metrics/AUROC50-95  metrics/E-AURC50  metrics/E-AURC50-95
# 7           0.93659             0.95058           0.02296              0.01540
# 83          0.89479             0.90325           0.02971              0.01928
# 75          0.89488             0.90271           0.02965              0.01925
# 28          0.89528             0.90352           0.02964              0.01921
# 62          0.89512             0.90284           0.02969              0.01927
# 📁 Saved figure: tuning_config_mc_dropout_rate_metrics_mAP50B_vs_metrics_mUE50.png and tuning_config_mc_dropout_rate_metrics_mAP50B_vs_metrics_mUE50.pdf
# 📁 Saved figure: tuning_config_num_mc_forward_passes_metrics_mAP50B_vs_metrics_mUE50.png and tuning_config_num_mc_forward_passes_metrics_mAP50B_vs_metrics_mUE50.pdf

# %%
df = pd.read_csv('../../results/tuning/edl-meh/results.csv')
plot_tuning_results(df, color_by='config/meh_lambda_activation_idx', show=True)
plot_tuning_results(df, color_by='config/edl_weight');
# Out:
#     fitness  config/meh_lambda_activation_idx  config/edl_weight  \
# 38  1.29141                                 1           1.657887
# 72  1.29109                                 1           2.396082
# 10  1.29108                                 2           4.735188
# 25  1.29105                                 1           0.224968
# 97  1.29104                                 1           4.812101
#
#                                           config/data  config/exist_ok  \
# 38  cityscapes-train-kitti-val-from-coco80-tuning....             True
# 72  cityscapes-train-kitti-val-from-coco80-tuning....             True
# 10  cityscapes-train-kitti-val-from-coco80-tuning....             True
# 25  cityscapes-train-kitti-val-from-coco80-tuning....             True
# 97  cityscapes-train-kitti-val-from-coco80-tuning....             True
#
#     config/epochs  config/imgsz  config/rect  config/save  config/fraction  \
# 38             50           640        False        False              1.0
# 72             50           640        False        False              1.0
# 10             50           640        False        False              1.0
# 25             50           640        False        False              1.0
# 97             50           640        False        False              1.0
#
#     config/val                                      config/freeze  config/box  \
# 38       False  ['0', '1', '2', '3', '4', '5', '6', '7', '8', ...         0.0
# 72       False  ['0', '1', '2', '3', '4', '5', '6', '7', '8', ...         0.0
# 10       False  ['0', '1', '2', '3', '4', '5', '6', '7', '8', ...         0.0
# 25       False  ['0', '1', '2', '3', '4', '5', '6', '7', '8', ...         0.0
# 97       False  ['0', '1', '2', '3', '4', '5', '6', '7', '8', ...         0.0
#
#     config/dfl  config/cls config/optimizer  config/lr0  config/lrf  \
# 38         0.0         1.0              SGD       0.001       0.001
# 72         0.0         1.0              SGD       0.001       0.001
# 10         0.0         1.0              SGD       0.001       0.001
# 25         0.0         1.0              SGD       0.001       0.001
# 97         0.0         1.0              SGD       0.001       0.001
#
#     config/momentum  config/weight_decay  config/batch  metrics/precision(B)  \
# 38              0.9               0.0005            16               0.54203
# 72              0.9               0.0005            16               0.54008
# 10              0.9               0.0005            16               0.53504
# 25              0.9               0.0005            16               0.54229
# 97              0.9               0.0005            16               0.53864
#
#     metrics/recall(B)  metrics/mAP50(B)  metrics/mAP50-95(B)  metrics/mUE50  \
# 38            0.38974           0.41099              0.21819        0.11958
# 72            0.39060           0.41051              0.21771        0.11942
# 10            0.39217           0.41045              0.21766        0.11937
# 25            0.38972           0.41007              0.21758        0.11902
# 97            0.39114           0.40999              0.21739        0.11895
#
#     metrics/mUE50_thres  metrics/mUE50-95  metrics/mUE50-95_thres  \
# 38              0.99707           0.08866                 0.99609
# 72              0.99707           0.08887                 0.99614
# 10              0.99707           0.08897                 0.99614
# 25              0.99707           0.08874                 0.99614
# 97              0.99756           0.08822                 0.99663
#
#     metrics/mUE50_correct  metrics/mUE50_incorrect  metrics/mUE50-95_correct  \
# 38                0.08286                  0.03672                   0.05997
# 72                0.08259                  0.03683                   0.05957
# 10                0.08252                  0.03686                   0.05960
# 25                0.08328                  0.03574                   0.06028
# 97                0.07394                  0.04500                   0.05680
#
#     metrics/mUE50-95_incorrect  metrics/FPR95_50  metrics/FPR95_50-95  \
# 38                     0.02869               1.0              0.52512
# 72                     0.02930               1.0              0.54655
# 10                     0.02937               1.0              0.52516
# 25                     0.02846               1.0              0.54486
# 97                     0.03141               1.0              0.58698
#
#     metrics/AUROC50  metrics/AUROC50-95  metrics/E-AURC50  metrics/E-AURC50-95
# 38          0.93230             0.95199           0.01776              0.01100
# 72          0.93233             0.95209           0.01776              0.01099
# 10          0.93253             0.95208           0.01774              0.01098
# 25          0.93256             0.95181           0.01752              0.01084
# 97          0.93341             0.95331           0.01660              0.01023
# 📁 Saved figure: tuning_config_meh_lambda_activation_idx_metrics_mAP50B_vs_metrics_mUE50.png and tuning_config_meh_lambda_activation_idx_metrics_mAP50B_vs_metrics_mUE50.pdf
# 📁 Saved figure: tuning_config_edl_weight_metrics_mAP50B_vs_metrics_mUE50.png and tuning_config_edl_weight_metrics_mAP50B_vs_metrics_mUE50.pdf
