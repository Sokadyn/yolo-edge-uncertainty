# %%
import os
import sys
import json

# allow importing from parent directory
current_folder = globals()['_dh'][0]
data_location = os.path.join(current_folder,'data.csv')
sys.path.append(os.path.abspath(os.path.join(os.path.dirname(data_location), '../..')))

import pandas as pd
from matplotlib import pyplot as plt
from utlis_results import plot_tuning_results

from ultralytics import settings
settings.update({"sync": False})

pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 200)

FONT_SMALL = 16
FONT_MEDIUM = 18
FONT_LARGE = 20

plt.rcParams['font.size'] = FONT_LARGE
plt.rcParams['axes.labelsize'] = FONT_MEDIUM
plt.rcParams['xtick.labelsize'] = FONT_SMALL
plt.rcParams['ytick.labelsize'] = FONT_SMALL
plt.rcParams['legend.fontsize'] = FONT_SMALL
plt.rcParams['figure.titlesize'] = FONT_MEDIUM
plt.rcParams['axes.titlesize'] = FONT_MEDIUM
plt.rcParams['figure.figsize'] = (16, 8)

# %%
df = pd.read_csv('../../results/tuning/ensemble/results.csv')
plot_tuning_results(df, color_by='config/ensemble_dropout_rate', show=True)
plot_tuning_results(df, color_by='config/num_ensemble_heads');
# Out:
#     fitness  config/ensemble_dropout_rate  config/num_ensemble_heads  \
# 19  1.25869                      0.119885                          9
# 71  1.25861                      0.188759                          3
# 45  1.25850                      0.032788                          9
# 82  1.25813                      0.183838                          3
# 38  1.25803                      0.161093                          3
#
#                                           config/data  config/exist_ok  \
# 19  cityscapes-train-kitti-val-from-coco80-tuning....             True
# 71  cityscapes-train-kitti-val-from-coco80-tuning....             True
# 45  cityscapes-train-kitti-val-from-coco80-tuning....             True
# 82  cityscapes-train-kitti-val-from-coco80-tuning....             True
# 38  cityscapes-train-kitti-val-from-coco80-tuning....             True
#
#     config/epochs  config/imgsz  config/rect  config/save  config/fraction  \
# 19             12           640        False        False              1.0
# 71             12           640        False        False              1.0
# 45             12           640        False        False              1.0
# 82             12           640        False        False              1.0
# 38             12           640        False        False              1.0
#
#     config/val                                      config/freeze  config/box  \
# 19       False  ['0', '1', '2', '3', '4', '5', '6', '7', '8', ...         0.0
# 71       False  ['0', '1', '2', '3', '4', '5', '6', '7', '8', ...         0.0
# 45       False  ['0', '1', '2', '3', '4', '5', '6', '7', '8', ...         0.0
# 82       False  ['0', '1', '2', '3', '4', '5', '6', '7', '8', ...         0.0
# 38       False  ['0', '1', '2', '3', '4', '5', '6', '7', '8', ...         0.0
#
#     config/dfl  config/cls  metrics/precision(B)  metrics/recall(B)  \
# 19         0.0         1.0               0.51181            0.37783
# 71         0.0         1.0               0.49584            0.39157
# 45         0.0         1.0               0.51195            0.37592
# 82         0.0         1.0               0.49593            0.38997
# 38         0.0         1.0               0.49045            0.39152
#
#     metrics/mAP50(B)  metrics/mAP50-95(B)  metrics/mUE50  metrics/mUE50_thres  \
# 19           0.41165              0.21439        0.15296              0.26660
# 71           0.41353              0.21376        0.15492              0.22559
# 45           0.40934              0.21414        0.15084              0.29907
# 82           0.41308              0.21369        0.15495              0.22485
# 38           0.41151              0.21305        0.15348              0.22111
#
#     metrics/mUE50-95  metrics/mUE50-95_thres  metrics/mUE50_correct  \
# 19           0.12918                 0.20214                0.09707
# 71           0.13241                 0.16961                0.09680
# 45           0.12753                 0.22280                0.09353
# 82           0.13244                 0.16720                0.09680
# 38           0.13081                 0.16949                0.09720
#
#     metrics/mUE50_incorrect  metrics/mUE50-95_correct  \
# 19                  0.05589                   0.08510
# 71                  0.05812                   0.08667
# 45                  0.05731                   0.08349
# 82                  0.05816                   0.08728
# 38                  0.05628                   0.08558
#
#     metrics/mUE50-95_incorrect  metrics/FPR95_50  metrics/FPR95_50-95  \
# 19                     0.04408           0.53663              0.47587
# 71                     0.04574           0.55622              0.50492
# 45                     0.04404           0.51410              0.45923
# 82                     0.04515           0.55390              0.50261
# 38                     0.04523           0.54812              0.49739
#
#     metrics/AUROC50  metrics/AUROC50-95  metrics/E-AURC50  metrics/E-AURC50-95
# 19          0.91214             0.92769           0.02142              0.01348
# 71          0.90903             0.92377           0.02330              0.01477
# 45          0.91478             0.93005           0.02022              0.01270
# 82          0.90903             0.92385           0.02328              0.01476
# 38          0.91026             0.92497           0.02272              0.01440

# %%
df = pd.read_csv('../../results/tuning/mc-dropout/results.csv')
plot_tuning_results(df, color_by='config/mc_dropout_rate', show=True)
plot_tuning_results(df, color_by='config/num_mc_forward_passes');
# Out:
#     fitness  config/mc_dropout_rate  config/num_mc_forward_passes  \
# 30  1.30954                0.128215                            15
# 25  1.30947                0.129404                             5
# 92  1.30884                0.126235                            15
# 72  1.27635                0.002278                            10
# 95  1.27517                0.005892                            20
#
#                                           config/data  config/exist_ok  \
# 30  cityscapes-train-kitti-val-from-coco80-tuning....             True
# 25  cityscapes-train-kitti-val-from-coco80-tuning....             True
# 92  cityscapes-train-kitti-val-from-coco80-tuning....             True
# 72  cityscapes-train-kitti-val-from-coco80-tuning....             True
# 95  cityscapes-train-kitti-val-from-coco80-tuning....             True
#
#     config/epochs  config/imgsz  config/rect  config/save  config/fraction  \
# 30             12           640        False        False              1.0
# 25             12           640        False        False              1.0
# 92             12           640        False        False              1.0
# 72             12           640        False        False              1.0
# 95             12           640        False        False              1.0
#
#     config/val                                      config/freeze  config/box  \
# 30       False  ['0', '1', '2', '3', '4', '5', '6', '7', '8', ...         0.0
# 25       False  ['0', '1', '2', '3', '4', '5', '6', '7', '8', ...         0.0
# 92       False  ['0', '1', '2', '3', '4', '5', '6', '7', '8', ...         0.0
# 72       False  ['0', '1', '2', '3', '4', '5', '6', '7', '8', ...         0.0
# 95       False  ['0', '1', '2', '3', '4', '5', '6', '7', '8', ...         0.0
#
#     config/dfl  config/cls  metrics/precision(B)  metrics/recall(B)  \
# 30         0.0         1.0               0.52878            0.36451
# 25         0.0         1.0               0.51112            0.36874
# 92         0.0         1.0               0.52571            0.36677
# 72         0.0         1.0               0.52649            0.36894
# 95         0.0         1.0               0.52213            0.36827
#
#     metrics/mAP50(B)  metrics/mAP50-95(B)  metrics/mUE50  metrics/mUE50_thres  \
# 30           0.38065              0.19874        0.07111              1.60938
# 25           0.37813              0.19702        0.06866              1.34863
# 92           0.38057              0.19880        0.07173              1.61816
# 72           0.37613              0.19587        0.09978              0.89111
# 95           0.37529              0.19547        0.10012              0.93213
#
#     metrics/mUE50-95  metrics/mUE50-95_thres  metrics/mUE50_correct  \
# 30           0.06467                 1.20469                0.01045
# 25           0.06290                 1.11152                0.02002
# 92           0.06523                 1.20898                0.01003
# 72           0.08440                 0.62844                0.04525
# 95           0.08444                 0.59880                0.04352
#
#     metrics/mUE50_incorrect  metrics/mUE50-95_correct  \
# 30                  0.06066                   0.01857
# 25                  0.04864                   0.02161
# 92                  0.06170                   0.01841
# 72                  0.05453                   0.04152
# 95                  0.05660                   0.04344
#
#     metrics/mUE50-95_incorrect  metrics/FPR95_50  metrics/FPR95_50-95  \
# 30                     0.04611           0.09426              0.08188
# 25                     0.04129           0.09003              0.07752
# 92                     0.04681           0.09553              0.08208
# 72                     0.04288           0.15340              0.13152
# 95                     0.04100           0.15395              0.13082
#
#     metrics/AUROC50  metrics/AUROC50-95  metrics/E-AURC50  metrics/E-AURC50-95
# 30          0.96759             0.97638           0.00977              0.00649
# 25          0.96828             0.97722           0.00915              0.00609
# 92          0.96735             0.97599           0.00982              0.00652
# 72          0.96951             0.97600           0.01217              0.00810
# 95          0.96797             0.97489           0.01245              0.00827

# %%
df = pd.read_csv('../../results/tuning/edl-meh/results.csv')
plot_tuning_results(df, color_by='config/num_dirichlet_samples', show=True)
plot_tuning_results(df, color_by='config/edl_weight');
# Out:
#     fitness  config/edl_weight  config/num_dirichlet_samples  \
# 36  1.27823           4.014570                            20
# 24  1.27813           4.597721                            20
# 7   1.27808           1.027819                            20
# 97  1.27801           1.583453                            20
# 8   1.27775           1.296284                            20
#
#                                           config/data  config/exist_ok  \
# 36  cityscapes-train-kitti-val-from-coco80-tuning....             True
# 24  cityscapes-train-kitti-val-from-coco80-tuning....             True
# 7   cityscapes-train-kitti-val-from-coco80-tuning....             True
# 97  cityscapes-train-kitti-val-from-coco80-tuning....             True
# 8   cityscapes-train-kitti-val-from-coco80-tuning....             True
#
#     config/epochs  config/imgsz  config/rect  config/save  config/fraction  \
# 36             12           640        False        False              1.0
# 24             12           640        False        False              1.0
# 7              12           640        False        False              1.0
# 97             12           640        False        False              1.0
# 8              12           640        False        False              1.0
#
#     config/val                                      config/freeze  config/box  \
# 36       False  ['0', '1', '2', '3', '4', '5', '6', '7', '8', ...         0.0
# 24       False  ['0', '1', '2', '3', '4', '5', '6', '7', '8', ...         0.0
# 7        False  ['0', '1', '2', '3', '4', '5', '6', '7', '8', ...         0.0
# 97       False  ['0', '1', '2', '3', '4', '5', '6', '7', '8', ...         0.0
# 8        False  ['0', '1', '2', '3', '4', '5', '6', '7', '8', ...         0.0
#
#     config/dfl  config/cls  metrics/precision(B)  metrics/recall(B)  \
# 36         0.0         1.0               0.51686            0.37394
# 24         0.0         1.0               0.50350            0.38186
# 7          0.0         1.0               0.50996            0.37423
# 97         0.0         1.0               0.50349            0.38122
# 8          0.0         1.0               0.49932            0.38123
#
#     metrics/mAP50(B)  metrics/mAP50-95(B)  metrics/mUE50  metrics/mUE50_thres  \
# 36           0.40560              0.21190        0.12737              3.29297
# 24           0.40552              0.21195        0.12739              3.29102
# 7            0.40560              0.21204        0.12752              3.29297
# 97           0.40525              0.21192        0.12724              3.29102
# 8            0.40520              0.21177        0.12745              3.29297
#
#     metrics/mUE50-95  metrics/mUE50-95_thres  metrics/mUE50_correct  \
# 36           0.09672                 3.28242                0.08236
# 24           0.09660                 3.28340                0.08574
# 7            0.09660                 3.28242                0.08270
# 97           0.09653                 3.28320                0.08561
# 8            0.09692                 3.28242                0.08241
#
#     metrics/mUE50_incorrect  metrics/mUE50-95_correct  \
# 36                  0.04501                   0.06138
# 24                  0.04165                   0.06028
# 7                   0.04482                   0.06107
# 97                  0.04163                   0.06058
# 8                   0.04505                   0.06146
#
#     metrics/mUE50-95_incorrect  metrics/FPR95_50  metrics/FPR95_50-95  \
# 36                     0.03535           0.87296              0.52172
# 24                     0.03632           0.87325              0.52159
# 7                      0.03552           0.87302              0.52139
# 97                     0.03595           0.87337              0.52162
# 8                      0.03547           0.87316              0.52256
#
#     metrics/AUROC50  metrics/AUROC50-95  metrics/E-AURC50  metrics/E-AURC50-95
# 36          0.92532             0.94722           0.01872              0.01183
# 24          0.92483             0.94702           0.01884              0.01193
# 7           0.92502             0.94682           0.01880              0.01190
# 97          0.92543             0.94716           0.01875              0.01189
# 8           0.92512             0.94701           0.01885              0.01192
