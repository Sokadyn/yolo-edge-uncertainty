# %%
import os
import sys

# allow importing from parent directory
current_folder = globals()['_dh'][0]
data_location = os.path.join(current_folder,'data.csv')
sys.path.append(os.path.abspath(os.path.join(os.path.dirname(data_location), '..')))

import pandas as pd
from matplotlib import pyplot as plt

pd.set_option('display.max_columns', None)

from utlis_results import load_results_data, format_model_names, create_dual_barplots, create_radar_chart, create_extended_barplots

# %%
datasets, train_dataset_path = load_results_data()
datasets, names_title_case = format_model_names(datasets)

create_extended_barplots(datasets, train_dataset_path)
# Out:
# Results folder: data_splits_and_models
# Train dataset path: train-kitti-from-coco80
# Processing dataset: val-raincityscapes-from-coco80
#                   metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# name
# base-pretrained               0.367428           0.241466          0.259274
# base-confidence               0.576457           0.117217          0.227690
# base-uncertainty              0.576457           0.117217          0.227690
# ensemble                      0.244290           0.116936          0.123036
# mc-dropout                    0.575602           0.117289          0.227126
# edl-meh                       0.245705           0.115760          0.133539
#
#                   metrics/mAP50-95(B)  metrics/mUE50  metrics/mUE50_thres  \
# name
# base-pretrained              0.165380       0.202485                 0.96
# base-confidence              0.172817       0.180794                 0.96
# ...
